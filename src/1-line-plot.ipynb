# %% [markdown]
# ### Exercise 1: Line Plot Customization

# %%
# TASK: Create a line plot with x values ranging from 0 to 10 and y values as the square of x.
# Customize the plot by adding a title, labels for both axes, and a grid.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = x ** 2

# %%
plt.title('Line Plot of y = x^2')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.grid(True)
plt.legend()


plt.show()
# Out:
# /tmp/ipykernel_3242/3350824914.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# AKSHAY RAJU
